# %%
import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
import random
import datetime
import webbrowser
import requests 
import time
from pygame import mixer
import billboard 
from matplotlib import pyplot as plt

from googlesearch import search
from nltk.stem import WordNetLemmatizer
from covid import Covid

lemmatizer=WordNetLemmatizer()

words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file=open('intents.json').read()
intents=json.loads(data_file) 

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w=nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag'])) 
   
        if intent['tag'] not in classes:
            classes.append(intent['tag']) 
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb')) 
#training data
training=[]
output_empty=[0]*len(classes) 

for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ] 
    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0) 
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1
    
    training.append([bag,output_row])
    
random.shuffle(training)
training=np.array(training)  
X_train=list(training[:,0])
y_train=list(training[:,1])  

#Model
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(X_train[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]),activation='softmax'))

adam=keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)
weights=model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)    
model.save('mymodel.h5',weights)


from keras.models import load_model
model = load_model('mymodel.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

#Predict
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))
    
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]
    
    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

def get_response(return_list,intents_json):
    
    if len(return_list)==0:
        tag='noanswer'
    else:    
        tag=return_list[0]['intent']
    if tag=='datetime':        
        print(time.strftime("%A"))
        print (time.strftime("%d %B %Y"))
        print (time.strftime("%H:%M:%S"))

    if tag=='google':
        query=input('Enter query...')
        chrome_path = r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe %s'
        for url in search(query, tld="co.in", num=1, stop = 1, pause = 2):
            webbrowser.open("https://google.com/search?q=%s" % query)
    if tag=='weather':
        api_key='987f44e8c16780be8c85e25a409ed07b'
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        city_name = input("Enter city name : ")
        complete_url = base_url + "appid=" + api_key + "&q=" + city_name
        response = requests.get(complete_url) 
        x=response.json()
        print('Present temp.: ',round(x['main']['temp']-273,2),'celcius ')
        print('Feels Like:: ',round(x['main']['feels_like']-273,2),'celcius ')
        print(x['weather'][0]['main'])
        
    if tag=='news':
        main_url = " http://newsapi.org/v2/top-headlines?country=in&apiKey=bc88c2e1ddd440d1be2cb0788d027ae2"
        open_news_page = requests.get(main_url).json()
        article = open_news_page["articles"]
        results = [] 
          
        for ar in article: 
            results.append([ar["title"],ar["url"]]) 
          
        for i in range(10): 
            print(i + 1, results[i][0])
            print(results[i][1],'\n')
            
    
    if tag=='song':
        chart=billboard.ChartData('hot-100')
        print('The top 10 songs at the moment are:')
        for i in range(10):
            song=chart[i]
            print(song.title,'- ',song.artist)
    if tag=='timer':        
        mixer.init()
        x=input('Minutes to timer..')
        time.sleep(float(x)*60)
        mixer.music.load('Handbell-ringing-sound-effect.mp3')
        mixer.music.play()
    if tag=="covid19":
        covid = Covid()
        x=input('Enter the country name').lower()
        if x=="world":
            covid=Covid(source="worldometers")
            confirmed = covid.get_total_confirmed_cases()
            print('Confirmed :', end =" ")
            print(confirmed)

            active = covid.get_total_active_cases()
            print("Active:", end =" ")
            print(active)

            recovered = covid.get_total_recovered()
            print('Recovered:', end =" ")
            print(recovered)

            deaths = covid.get_total_deaths()
            print('Deaths:', end =" ")
            print(deaths)
        
        else:
            country = covid.get_status_by_country_name(x)

            data ={
                    key:country[key]
                    for key in country.keys() and {'confirmed', 
                                                 'active',
                                                 'deaths',
                                                 'recovered'}
                }
  
        print(data)
#     if tag=='covid19':
        
#         covid19=COVID19Py.COVID19(data_source='csbs')
#         country=input('Enter Location...')
        
#         if country.lower()=='world':
#             latest_world=covid19.getLatest()
#             print('Confirmed:',latest_world['confirmed'],' Deaths:',latest_world['deaths'])
        
#         else:
                   
#             latest=covid19.getLocations()
            
#             latest_conf=[]
#             latest_deaths=[]
#             for i in range(len(latest)):
                
#                 if latest[i]['country'].lower()== country.lower():
#                     latest_conf.append(latest[i]['latest']['confirmed'])
#                     latest_deaths.append(latest[i]['latest']['deaths'])
#             latest_conf=np.array(latest_conf)
#             latest_deaths=np.array(latest_deaths)
#             print('Confirmed: ',np.sum(latest_conf),'Deaths: ',np.sum(latest_deaths))
    

    list_of_intents= intents_json['intents']    
    for i in list_of_intents:
        if tag==i['tag'] :
            result= random.choice(i['responses'])
    return result

def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response
texts = []
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\Tilakavati\AppData\Local\Temp\ipykernel_38440\376913231.py:63: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training=np.array(training)
# Epoch 1/200
# 12/12 [==============================] - 1s 4ms/step - loss: 3.4302 - accuracy: 0.0517
# Epoch 2/200
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4176 - accuracy: 0.0259
# Epoch 3/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3871 - accuracy: 0.0690
# Epoch 4/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3610 - accuracy: 0.0603
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3196 - accuracy: 0.0862
# Epoch 6/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3027 - accuracy: 0.1207
# Epoch 7/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2828 - accuracy: 0.0948
# Epoch 8/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2252 - accuracy: 0.1121
# Epoch 9/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1767 - accuracy: 0.1638
# Epoch 10/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1550 - accuracy: 0.1121
# Epoch 11/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0091 - accuracy: 0.1724
# Epoch 12/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0121 - accuracy: 0.1897
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9163 - accuracy: 0.2155
# Epoch 14/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8325 - accuracy: 0.2328
# Epoch 15/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7713 - accuracy: 0.2328
# Epoch 16/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6611 - accuracy: 0.3017
# Epoch 17/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6109 - accuracy: 0.3017
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5348 - accuracy: 0.3017
# Epoch 19/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4662 - accuracy: 0.3362
# Epoch 20/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2860 - accuracy: 0.3362
# Epoch 21/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2743 - accuracy: 0.3448
# Epoch 22/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1537 - accuracy: 0.4310
# Epoch 23/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0572 - accuracy: 0.4052
# Epoch 24/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9064 - accuracy: 0.4914
# Epoch 25/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9410 - accuracy: 0.4310
# Epoch 26/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8415 - accuracy: 0.4914
# Epoch 27/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8421 - accuracy: 0.4741
# Epoch 28/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6714 - accuracy: 0.4914
# Epoch 29/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6455 - accuracy: 0.5862
# Epoch 30/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5323 - accuracy: 0.6379
# Epoch 31/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4396 - accuracy: 0.6207
# Epoch 32/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3714 - accuracy: 0.5948
# Epoch 33/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3626 - accuracy: 0.6207
# Epoch 34/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3352 - accuracy: 0.5862
# Epoch 35/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3099 - accuracy: 0.6207
# Epoch 36/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1745 - accuracy: 0.7069
# Epoch 37/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1270 - accuracy: 0.6552
# Epoch 38/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0480 - accuracy: 0.7155
# Epoch 39/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1699 - accuracy: 0.6552
# Epoch 40/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0785 - accuracy: 0.6724
# Epoch 41/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9197 - accuracy: 0.7759
# Epoch 42/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9609 - accuracy: 0.7328
# Epoch 43/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0016 - accuracy: 0.6983
# Epoch 44/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8814 - accuracy: 0.7672
# Epoch 45/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0434 - accuracy: 0.6897
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8973 - accuracy: 0.7155
# Epoch 47/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7845 - accuracy: 0.8103
# Epoch 48/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8017 - accuracy: 0.7586
# Epoch 49/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7910 - accuracy: 0.7759
# Epoch 50/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7135 - accuracy: 0.8362
# Epoch 51/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6419 - accuracy: 0.7845
# Epoch 52/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7297 - accuracy: 0.7759
# Epoch 53/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6392 - accuracy: 0.8276
# Epoch 54/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7915 - accuracy: 0.7586
# Epoch 55/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7371 - accuracy: 0.8362
# Epoch 56/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5905 - accuracy: 0.8362
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6575 - accuracy: 0.8017
# Epoch 58/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6145 - accuracy: 0.8448
# Epoch 59/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.8793
# Epoch 60/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.8621
# Epoch 61/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5067 - accuracy: 0.9052
# Epoch 62/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4568 - accuracy: 0.8707
# Epoch 63/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4736 - accuracy: 0.8621
# Epoch 64/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6297 - accuracy: 0.7931
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4778 - accuracy: 0.8534
# Epoch 66/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.8879
# Epoch 67/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.8190
# Epoch 68/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3740 - accuracy: 0.8966
# Epoch 69/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5170 - accuracy: 0.8448
# Epoch 70/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5933 - accuracy: 0.8190
# Epoch 71/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5097 - accuracy: 0.8448
# Epoch 72/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5118 - accuracy: 0.8621
# Epoch 73/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.8793
# Epoch 74/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8879
# Epoch 75/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3818 - accuracy: 0.8793
# Epoch 76/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8879
# Epoch 77/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.8534
# Epoch 78/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3546 - accuracy: 0.9138
# Epoch 79/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3140 - accuracy: 0.9310
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2982 - accuracy: 0.9052
# Epoch 81/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3413 - accuracy: 0.8707
# Epoch 82/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8966
# Epoch 83/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3601 - accuracy: 0.8448
# Epoch 84/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.9052
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 0.9224
# Epoch 86/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4349 - accuracy: 0.8793
# Epoch 87/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3614 - accuracy: 0.8879
# Epoch 88/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3048 - accuracy: 0.9224
# Epoch 89/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.9138
# Epoch 90/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3033 - accuracy: 0.8966
# Epoch 91/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3149 - accuracy: 0.8966
# Epoch 92/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3345 - accuracy: 0.8966
# Epoch 93/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3572 - accuracy: 0.9052
# Epoch 94/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2424 - accuracy: 0.9138
# Epoch 95/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.9052
# Epoch 96/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2855 - accuracy: 0.8879
# Epoch 97/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2882 - accuracy: 0.9138
# Epoch 98/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3045 - accuracy: 0.8966
# Epoch 99/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.9052
# Epoch 100/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2586 - accuracy: 0.9138
# Epoch 101/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2470 - accuracy: 0.9052
# Epoch 102/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.9397
# Epoch 103/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3055 - accuracy: 0.9052
# Epoch 104/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9569
# Epoch 105/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2370 - accuracy: 0.9224
# Epoch 106/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2106 - accuracy: 0.9483
# Epoch 107/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3170 - accuracy: 0.9310
# Epoch 108/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1878 - accuracy: 0.9397
# Epoch 109/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2537 - accuracy: 0.9397
# Epoch 110/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2288 - accuracy: 0.9310
# Epoch 111/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.9138
# Epoch 112/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3269 - accuracy: 0.8793
# Epoch 113/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1958 - accuracy: 0.9224
# Epoch 114/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9397
# Epoch 115/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.9569
# Epoch 116/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.9397
# Epoch 117/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1963 - accuracy: 0.9310
# Epoch 118/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2837 - accuracy: 0.9138
# Epoch 119/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.9310
# Epoch 120/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1514 - accuracy: 0.9741
# Epoch 121/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1486 - accuracy: 0.9483
# Epoch 122/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9655
# Epoch 123/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1849 - accuracy: 0.9569
# Epoch 124/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1727 - accuracy: 0.9569
# Epoch 125/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2104 - accuracy: 0.9397
# Epoch 126/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9483
# Epoch 127/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9483
# Epoch 128/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.9224
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1716 - accuracy: 0.9828
# Epoch 130/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2104 - accuracy: 0.9397
# Epoch 131/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2621 - accuracy: 0.9052
# Epoch 132/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2728 - accuracy: 0.9052
# Epoch 133/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9655
# Epoch 134/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1358 - accuracy: 0.9655
# Epoch 135/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9483
# Epoch 136/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2133 - accuracy: 0.9224
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1694 - accuracy: 0.9569
# Epoch 138/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9828
# Epoch 139/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 0.9483
# Epoch 140/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1801 - accuracy: 0.9569
# Epoch 141/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1682 - accuracy: 0.9483
# Epoch 142/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1404 - accuracy: 0.9483
# Epoch 143/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9569
# Epoch 144/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1453 - accuracy: 0.9483
# Epoch 145/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9310
# Epoch 146/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1017 - accuracy: 0.9828
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9483
# Epoch 148/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1789 - accuracy: 0.9569
# Epoch 149/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2070 - accuracy: 0.9310
# Epoch 150/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9741
# Epoch 151/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.9483
# Epoch 152/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9569
# Epoch 153/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9310
# Epoch 154/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.9569
# Epoch 155/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9914
# Epoch 156/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9741
# Epoch 157/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9655
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1312 - accuracy: 0.9828
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9310
# Epoch 160/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9310
# Epoch 161/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1698 - accuracy: 0.9569
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9483
# Epoch 163/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.9483
# Epoch 164/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1280 - accuracy: 0.9655
# Epoch 165/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9655
# Epoch 166/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.9828
# Epoch 167/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.9914
# Epoch 168/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1659 - accuracy: 0.9655
# Epoch 169/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1741 - accuracy: 0.9310
# Epoch 170/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9741
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9397
# Epoch 172/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 0.9569
# Epoch 173/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1790 - accuracy: 0.9310
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9741
# Epoch 175/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1564 - accuracy: 0.9483
# Epoch 176/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9828
# Epoch 177/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.9828
# Epoch 178/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9741
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1491 - accuracy: 0.9569
# Epoch 180/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9741
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 0.9828
# Epoch 182/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0852 - accuracy: 0.9828
# Epoch 183/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1163 - accuracy: 0.9655
# Epoch 184/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1193 - accuracy: 0.9828
# Epoch 185/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9741
# Epoch 186/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1548 - accuracy: 0.9483
# Epoch 187/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0949 - accuracy: 1.0000
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1654 - accuracy: 0.9569
# Epoch 189/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.9224
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 0.9741
# Epoch 191/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1018 - accuracy: 0.9655
# Epoch 192/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9655
# Epoch 193/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.9828
# Epoch 194/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9655
# Epoch 195/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9828
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9914
# Epoch 197/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1606 - accuracy: 0.9569
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9828
# Epoch 199/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9655
# Epoch 200/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9655

# %%
while(1):
    x=input()
    texts.append(x)
    print(response(x))
    if x.lower() in ['bye','goodbye','bye bye','see you']:  
        break
# Out:
# who is president of usa
# 1/1 [==============================] - 0s 43ms/step
# Joe Biden

# %%
import nltk
import pandas as pd

# Load EmoLex lexicon
nltk.download('nrc_lexicon')
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer

# Load EmoLex lexicon
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon

# Load AFINN lexicon
from afinn import Afinn
afn = Afinn()

# Define a function to extract emotions from a list of texts
def extract_emotions(texts):
    # Initialize the sentiment analyzer
    sid = SentimentIntensityAnalyzer()

    # Tokenize the texts and concatenate into one list
    tokens = []
    for text in texts:
        tokens += word_tokenize(text)

    # Remove stop words and punctuation
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.lower() not in stop_words and word.isalpha()]

    # Initialize emotion dictionary with all dimensions
    emotions = {'anger': 0, 'anticipation': 0, 'disgust': 0, 'fear': 0, 'joy': 0, 'sadness': 0, 'surprise': 0, 'trust': 0}

    # Get the sentiment score for the texts
    for text in texts:
        sentiment_scores = sid.polarity_scores(text)
        for key in emotions.keys():
            if key in sentiment_scores:
                emotions[key] += sentiment_scores[key]

    # Check for words in EmoLex lexicon
    for token in tokens:
        if token in opinion_lexicon.negative():
            emotions['anger'] += 1
            emotions['disgust'] += 1
            emotions['sadness'] += 1
            emotions['fear'] += 1
        elif token in opinion_lexicon.positive():
            emotions['anticipation'] += 1
            emotions['joy'] += 1
            emotions['trust'] += 1
            emotions['surprise'] += 1
        # Check for words in AFINN lexicon
        elif afn.score(token) > 0:
            emotions['anticipation'] += afn.score(token)
            emotions['joy'] += afn.score(token)
            emotions['trust'] += afn.score(token)
            emotions['surprise'] += afn.score(token)
        elif afn.score(token) < 0:
            emotions['anger'] += abs(afn.score(token))
            emotions['disgust'] += abs(afn.score(token))
            emotions['sadness'] += abs(afn.score(token))
            emotions['fear'] += abs(afn.score(token))
        # Check for words in EmoLex lexicon
        synsets = wn.synsets(token)
        if synsets:
            synset = synsets[0]
            for lemma in synset.lemmas():
                if lemma.name() in emotions.keys():
                    emotions[lemma.name()] += 1

    # Normalize emotion scores
    total_score = sum(emotions.values())

    return emotions

# Input texts to analyze
#texts = ["I'm so happy today!", "I'm really angry about this situation", "
#texts = ["I'm I'm really angry about this situation", "I'm feeling quite anxious before the big presentation", "The news of his death was so sad", "I feel very calm and sad today", "This roller coaster is making me feel so scared"]


emotions = extract_emotions(texts)
print(texts)
print(emotions)
#my_dict = {'a': 10, 'b': 5, 'c': 20}
max_key = max(emotions, key=emotions.get)
print(max_key)
# Out:
# [nltk_data] Error loading nrc_lexicon: Package 'nrc_lexicon' not found
# [nltk_data]     in index
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\Tilakavati\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# ['hi', 'how are you', 'fine ', 'are you free', 'what']
# {'anger': 0, 'anticipation': 2, 'disgust': 0, 'fear': 0, 'joy': 2, 'sadness': 0, 'surprise': 2, 'trust': 2}
# anticipation

# %%
import pandas as pd
import random

val = input("Do you want to listen to a song? Yes/No ")

if (val == ('yes' or 'Yes')):
    # Load Excel sheet into a DataFrame
    df = pd.read_excel('Songs.xlsx', sheet_name='Sheet1')

    # Select a specific column by column name
    selected_column = df[max_key]

    # Select a random index from the column
    random_index = random.randint(0, len(selected_column)-1)

    # Select the cell at the random index
    random_cell = selected_column[random_index]

    # Print the randomly selected cell
    print(random_cell)

    import webbrowser

    # Open a specific YouTube channel page
    username = random_cell
    url = f'https://www.youtube.com/results?search_query={username}'
    webbrowser.open(url)
    
elif (val==('No' or 'no')):
    print("Alright !, Good Bye !")

else:
    print("Sorry that is invalid input")
# Out:
# Do you want to listen to a song? Yes/No yes
# "Hall of Fame" by The Script

# %%
#Self learning
print('Help me Learn?')
tag=input('Please enter general category of your question  ')
flag=-1
for i in range(len(intents['intents'])):
    if tag.lower() in intents['intents'][i]['tag']:
        intents['intents'][i]['patterns'].append(input('Enter your message: '))
        intents['intents'][i]['responses'].append(input('Enter expected reply: '))        
        flag=1

if flag==-1:
    
    intents['intents'].append (
        {'tag':tag,
         'patterns': [input('Please enter your message')],
         'responses': [input('Enter expected reply')]})
    
with open('intents.json','w') as outfile:
    outfile.write(json.dumps(intents,indent=4))
# Out:
# Help me Learn?
